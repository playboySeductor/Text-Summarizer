# %%
# !pip install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: transformers in /usr/local/lib/python3.7/dist-packages (4.21.2)
# Requirement already satisfied: huggingface-hub<1.0,>=0.1.0 in /usr/local/lib/python3.7/dist-packages (from transformers) (0.9.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers) (2.23.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers) (4.12.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers) (3.8.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (1.21.6)
# Requirement already satisfied: tokenizers!=0.11.3,<0.13,>=0.11.1 in /usr/local/lib/python3.7/dist-packages (from transformers) (0.12.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from transformers) (21.3)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.7/dist-packages (from transformers) (6.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (2022.6.2)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers) (4.64.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0,>=0.1.0->transformers) (4.1.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->transformers) (3.0.9)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers) (3.8.1)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2022.6.15)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2.10)

# %%
from transformers import pipeline

# %%
summarizer=pipeline("summarization")
# Out:
# No model was supplied, defaulted to sshleifer/distilbart-cnn-12-6 and revision a4f8f3e (https://huggingface.co/sshleifer/distilbart-cnn-12-6).
# Using a pipeline without specifying a model name and revision in production is not recommended.

# %%
Article= """
 The cardiovascular and respiratory autonomic nervous regulation has been studied mainly by hemodynamic responses during different physical stressors . 
 In this study dynamics of autonomic response to an orthostatic challenge was investigated by hemodynamic variables and by diverse linear and nonlinear indices calculated from time series of beat to beat intervals respiratory cycle duration systolic and diastolic blood pressure . This study included 16 young female patients with vasovagal syncope and 12 age matched female controls . The subjects were enrolled in a head up tilt test breathing normally including 5min of baseline and 18min of 70 orthostatic phase . To increase the time resolution of the analysis the time series were segmented in five minute overlapping windows with a shift of 1min . Hemodynamic parameters did not show any statistical differences between SYN and CON . Time domain linear analysis revealed increased respiratory frequency and increased blood pressure variability in patients during OP meaning increased sympathetic activity and vagal withdrawal . Frequency domain analysis confirmed a predominance of sympathetic tone by steadily increased values of low over high frequency power in BBI and of low frequency power in SYS and DIA in patients during OP . The nonlinear analysis by symbolic dynamics seemed to be highly suitable for differentiation of SYN and CON in the early beginning of OP i.e . 5min after tilt up . In particular the index SYS plvar3 showed less patterns of low variability in patients reflecting a steadily increase in both BPV and sympathetic activity . The proposed dynamical analysis could lead to a better understanding of the temporal underlying mechanisms in healthy subjects and patients under orthostatic stress .
"""

# %%
summarizer(Article, max_length=150, min_length=30, do_sample=False)
# Out:
# [{'summary_text': ' The cardiovascular and respiratory autonomic nervous regulation has been studied mainly by hemodynamic responses during different physical stressors . The proposed dynamical analysis could lead to a better understanding of the temporal underlying mechanisms in healthy subjects and patients under orthostatic stress .'}]

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('fintest.csv')

# %%
for i in range(0,100):
  df["Abstract"].iloc[i]=str(df["Abstract"].iloc[i])

# %%
df["Abstract"].iloc[99]
# Out:
# ' We describe a method for a reconstructing piecewise helix curve from its 2D sketch . The system takes as input a hand drawn polygonal curve and generates a piecewise helix curve such that its orthogonal projection matches the input curve . The first step is an algorithm to generate a set of helices such that their orthogonal projection approximates the input curve . This step is followed by a global optimization to minimize the tangent discontinuity of the junctions of the helices while keeping the fitting error small .'

# %%
df1 = pd.DataFrame(columns = ['RHS'])

# %%
for i in range(0,100):
  # print(summarizer(df["Abstract"].iloc[i], max_length=100, min_length=30, do_sample=False))
  df1.loc[i] = [summarizer(df["Abstract"].iloc[i], max_length=100, min_length=30, do_sample=False)]
  print(df1)
  i=i+1
# Out:
#                                                  RHS
# 0  [{'summary_text': ' We explore the notion of a...
# 1  [{'summary_text': ' The high coupling between ...
#                                                  RHS
# 0  [{'summary_text': ' We explore the notion of a...
# 1  [{'summary_text': ' The high coupling between ...
#                                                  RHS
# 0  [{'summary_text': ' We explore the notion of a...
# 1  [{'summary_text': ' The high coupling between ...
# 2  [{'summary_text': ' A geometry seam consists o...
#                                                  RHS
# 0  [{'summary_text': ' We explore the notion of a...
# 1  [{'summary_text': ' The high coupling between ...
# 2  [{'summary_text': ' A geometry seam consists o...
# 3  [{'summary_text': ' This paper presents an alg...
#                                                  RHS
# 0  [{'summary_text': ' We explore the notion of a...
# 1  [{'summary_text': ' The high coupling between ...
# 2  [{'summary_text': ' A geometry seam consists o...
# 3  [{'summary_text': ' This paper presents an alg...
# 4  [{'summary_text': ' The proposed hybrid method...
#                                                  RHS
# 0  [{'summary_text': ' We explore the notion of a...
# 1  [{'summary_text': ' The high coupling between ...
# 2  [{'summary_text': ' A geometry seam consists o...
# 3  [{'summary_text': ' This paper presents an alg...
# 4  [{'summary_text': ' The proposed hybrid method...
# 5  [{'summary_text': ' In most cases designers ha...
#                                                  RHS
# 0  [{'summary_text': ' We explore the notion of a...
# 1  [{'summary_text': ' The high coupling between ...
# 2  [{'summary_text': ' A geometry seam consists o...
# 3  [{'summary_text': ' This paper presents an alg...
# 4  [{'summary_text': ' The proposed hybrid method...
# 5  [{'summary_text': ' In most cases designers ha...
# 6  [{'summary_text': ' PLM uses intelligent produ...
#                                                  RHS
# 0  [{'summary_text': ' We explore the notion of a...
# 1  [{'summary_text': ' The high coupling between ...
# 2  [{'summary_text': ' A geometry seam consists o...
# 3  [{'summary_text': ' This paper presents an alg...
# 4  [{'summary_text': ' The proposed hybrid method...
# 5  [{'summary_text': ' In most cases designers ha...
# 6  [{'summary_text': ' PLM uses intelligent produ...
# 7  [{'summary_text': ' Human body modeling is a c...
#                                                  RHS
# 0  [{'summary_text': ' We explore the notion of a...
# 1  [{'summary_text': ' The high coupling between ...
# 2  [{'summary_text': ' A geometry seam consists o...
# 3  [{'summary_text': ' This paper presents an alg...
# 4  [{'summary_text': ' The proposed hybrid method...
# 5  [{'summary_text': ' In most cases designers ha...
# 6  [{'summary_text': ' PLM uses intelligent produ...
# 7  [{'summary_text': ' Human body modeling is a c...
# 8  [{'summary_text': ' Family Mould Cavity Runner...
#                                                  RHS
# 0  [{'summary_text': ' We explore the notion of a...
# 1  [{'summary_text': ' The high coupling between ...
# 2  [{'summary_text': ' A geometry seam consists o...
# 3  [{'summary_text': ' This paper presents an alg...
# 4  [{'summary_text': ' The proposed hybrid method...
# 5  [{'summary_text': ' In most cases designers ha...
# 6  [{'summary_text': ' PLM uses intelligent produ...
# 7  [{'summary_text': ' Human body modeling is a c...
# 8  [{'summary_text': ' Family Mould Cavity Runner...
# 9  [{'summary_text': ' In this paper we present a...
#                                                   RHS
# 0   [{'summary_text': ' We explore the notion of a...
# 1   [{'summary_text': ' The high coupling between ...
# 2   [{'summary_text': ' A geometry seam consists o...
# 3   [{'summary_text': ' This paper presents an alg...
# 4   [{'summary_text': ' The proposed hybrid method...
# 5   [{'summary_text': ' In most cases designers ha...
# 6   [{'summary_text': ' PLM uses intelligent produ...
# 7   [{'summary_text': ' Human body modeling is a c...
# 8   [{'summary_text': ' Family Mould Cavity Runner...
# 9   [{'summary_text': ' In this paper we present a...
# 10  [{'summary_text': ' In an industrial context m...
#                                                   RHS
# 0   [{'summary_text': ' We explore the notion of a...
# 1   [{'summary_text': ' The high coupling between ...
# 2   [{'summary_text': ' A geometry seam consists o...
# 3   [{'summary_text': ' This paper presents an alg...
# 4   [{'summary_text': ' The proposed hybrid method...
# 5   [{'summary_text': ' In most cases designers ha...
# 6   [{'summary_text': ' PLM uses intelligent produ...
# 7   [{'summary_text': ' Human body modeling is a c...
# 8   [{'summary_text': ' Family Mould Cavity Runner...
# 9   [{'summary_text': ' In this paper we present a...
# 10  [{'summary_text': ' In an industrial context m...
# 11  [{'summary_text': ' We present an algorithm fo...
#                                                   RHS
# 0   [{'summary_text': ' We explore the notion of a...
# 1   [{'summary_text': ' The high coupling between ...
# 2   [{'summary_text': ' A geometry seam consists o...
# 3   [{'summary_text': ' This paper presents an alg...
# 4   [{'summary_text': ' The proposed hybrid method...
# 5   [{'summary_text': ' In most cases designers ha...
# 6   [{'summary_text': ' PLM uses intelligent produ...
# 7   [{'summary_text': ' Human body modeling is a c...
# 8   [{'summary_text': ' Family Mould Cavity Runner...
# 9   [{'summary_text': ' In this paper we present a...
# 10  [{'summary_text': ' In an industrial context m...
# 11  [{'summary_text': ' We present an algorithm fo...
# 12  [{'summary_text': ' Solving polynomial systems...
#                                                   RHS
# 0   [{'summary_text': ' We explore the notion of a...
# 1   [{'summary_text': ' The high coupling between ...
# 2   [{'summary_text': ' A geometry seam consists o...
# 3   [{'summary_text': ' This paper presents an alg...
# 4   [{'summary_text': ' The proposed hybrid method...
# 5   [{'summary_text': ' In most cases designers ha...
# 6   [{'summary_text': ' PLM uses intelligent produ...
# 7   [{'summary_text': ' Human body modeling is a c...
# 8   [{'summary_text': ' Family Mould Cavity Runner...
# 9   [{'summary_text': ' In this paper we present a...
# 10  [{'summary_text': ' In an industrial context m...
# 11  [{'summary_text': ' We present an algorithm fo...
# 12  [{'summary_text': ' Solving polynomial systems...
# 13  [{'summary_text': ' The PAL which has a front ...
# Your max_length is set to 100, but you input_length is only 90. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=45)
#                                                   RHS
# 0   [{'summary_text': ' We explore the notion of a...
# 1   [{'summary_text': ' The high coupling between ...
# 2   [{'summary_text': ' A geometry seam consists o...
# 3   [{'summary_text': ' This paper presents an alg...
# 4   [{'summary_text': ' The proposed hybrid method...
# 5   [{'summary_text': ' In most cases designers ha...
# 6   [{'summary_text': ' PLM uses intelligent produ...
# 7   [{'summary_text': ' Human body modeling is a c...
# 8   [{'summary_text': ' Family Mould Cavity Runner...
# 9   [{'summary_text': ' In this paper we present a...
# 10  [{'summary_text': ' In an industrial context m...
# 11  [{'summary_text': ' We present an algorithm fo...
# 12  [{'summary_text': ' Solving polynomial systems...
# 13  [{'summary_text': ' The PAL which has a front ...
# 14  [{'summary_text': ' There is a growing need wi...
#                                                   RHS
# 0   [{'summary_text': ' We explore the notion of a...
# 1   [{'summary_text': ' The high coupling between ...
# 2   [{'summary_text': ' A geometry seam consists o...
# 3   [{'summary_text': ' This paper presents an alg...
# 4   [{'summary_text': ' The proposed hybrid method...
# 5   [{'summary_text': ' In most cases designers ha...
# 6   [{'summary_text': ' PLM uses intelligent produ...
# 7   [{'summary_text': ' Human body modeling is a c...
# 8   [{'summary_text': ' Family Mould Cavity Runner...
# 9   [{'summary_text': ' In this paper we present a...
# 10  [{'summary_text': ' In an industrial context m...
# 11  [{'summary_text': ' We present an algorithm fo...
# 12  [{'summary_text': ' Solving polynomial systems...
# 13  [{'summary_text': ' The PAL which has a front ...
# 14  [{'summary_text': ' There is a growing need wi...
# 15  [{'summary_text': ' Longest edge refinement al...
#                                                   RHS
# 0   [{'summary_text': ' We explore the notion of a...
# 1   [{'summary_text': ' The high coupling between ...
# 2   [{'summary_text': ' A geometry seam consists o...
# 3   [{'summary_text': ' This paper presents an alg...
# 4   [{'summary_text': ' The proposed hybrid method...
# 5   [{'summary_text': ' In most cases designers ha...
# 6   [{'summary_text': ' PLM uses intelligent produ...
# 7   [{'summary_text': ' Human body modeling is a c...
# 8   [{'summary_text': ' Family Mould Cavity Runner...
# 9   [{'summary_text': ' In this paper we present a...
# 10  [{'summary_text': ' In an industrial context m...
# 11  [{'summary_text': ' We present an algorithm fo...
# 12  [{'summary_text': ' Solving polynomial systems...
# 13  [{'summary_text': ' The PAL which has a front ...
# 14  [{'summary_text': ' There is a growing need wi...
# 15  [{'summary_text': ' Longest edge refinement al...
# 16  [{'summary_text': ' The wide adoption of agile...
#                                                   RHS
# 0   [{'summary_text': ' We explore the notion of a...
# 1   [{'summary_text': ' The high coupling between ...
# 2   [{'summary_text': ' A geometry seam consists o...
# 3   [{'summary_text': ' This paper presents an alg...
# 4   [{'summary_text': ' The proposed hybrid method...
# 5   [{'summary_text': ' In most cases designers ha...
# 6   [{'summary_text': ' PLM uses intelligent produ...
# 7   [{'summary_text': ' Human body modeling is a c...
# 8   [{'summary_text': ' Family Mould Cavity Runner...
# 9   [{'summary_text': ' In this paper we present a...
# 10  [{'summary_text': ' In an industrial context m...
# 11  [{'summary_text': ' We present an algorithm fo...
# 12  [{'summary_text': ' Solving polynomial systems...
# 13  [{'summary_text': ' The PAL which has a front ...
# 14  [{'summary_text': ' There is a growing need wi...
# 15  [{'summary_text': ' Longest edge refinement al...
# 16  [{'summary_text': ' The wide adoption of agile...
# 17  [{'summary_text': ' Ruled surfaces play an imp...
#                                                   RHS
# 0   [{'summary_text': ' We explore the notion of a...
# 1   [{'summary_text': ' The high coupling between ...
# 2   [{'summary_text': ' A geometry seam consists o...
# 3   [{'summary_text': ' This paper presents an alg...
# 4   [{'summary_text': ' The proposed hybrid method...
# 5   [{'summary_text': ' In most cases designers ha...
# 6   [{'summary_text': ' PLM uses intelligent produ...
# 7   [{'summary_text': ' Human body modeling is a c...
# 8   [{'summary_text': ' Family Mould Cavity Runner...
# 9   [{'summary_text': ' In this paper we present a...
# 10  [{'summary_text': ' In an industrial context m...
# 11  [{'summary_text': ' We present an algorithm fo...
# 12  [{'summary_text': ' Solving polynomial systems...
# 13  [{'summary_text': ' The PAL which has a front ...
# 14  [{'summary_text': ' There is a growing need wi...
# 15  [{'summary_text': ' Longest edge refinement al...
# 16  [{'summary_text': ' The wide adoption of agile...
# 17  [{'summary_text': ' Ruled surfaces play an imp...
# 18  [{'summary_text': ' Design is an interactive a...
#                                                   RHS
# 0   [{'summary_text': ' We explore the notion of a...
# 1   [{'summary_text': ' The high coupling between ...
# 2   [{'summary_text': ' A geometry seam consists o...
# 3   [{'summary_text': ' This paper presents an alg...
# 4   [{'summary_text': ' The proposed hybrid method...
# 5   [{'summary_text': ' In most cases designers ha...
# 6   [{'summary_text': ' PLM uses intelligent produ...
# 7   [{'summary_text': ' Human body modeling is a c...
# 8   [{'summary_text': ' Family Mould Cavity Runner...
# 9   [{'summary_text': ' In this paper we present a...
# 10  [{'summary_text': ' In an industrial context m...
# 11  [{'summary_text': ' We present an algorithm fo...
# 12  [{'summary_text': ' Solving polynomial systems...
# 13  [{'summary_text': ' The PAL which has a front ...
# 14  [{'summary_text': ' There is a growing need wi...
# 15  [{'summary_text': ' Longest edge refinement al...
# 16  [{'summary_text': ' The wide adoption of agile...
# 17  [{'summary_text': ' Ruled surfaces play an imp...
# 18  [{'summary_text': ' Design is an interactive a...
# 19  [{'summary_text': ' A novel approach for plann...
#                                                   RHS
# 0   [{'summary_text': ' We explore the notion of a...
# 1   [{'summary_text': ' The high coupling between ...
# 2   [{'summary_text': ' A geometry seam consists o...
# 3   [{'summary_text': ' This paper presents an alg...
# 4   [{'summary_text': ' The proposed hybrid method...
# 5   [{'summary_text': ' In most cases designers ha...
# 6   [{'summary_text': ' PLM uses intelligent produ...
# 7   [{'summary_text': ' Human body modeling is a c...
# 8   [{'summary_text': ' Family Mould Cavity Runner...
# 9   [{'summary_text': ' In this paper we present a...
# 10  [{'summary_text': ' In an industrial context m...
# 11  [{'summary_text': ' We present an algorithm fo...
# 12  [{'summary_text': ' Solving polynomial systems...
# 13  [{'summary_text': ' The PAL which has a front ...
# 14  [{'summary_text': ' There is a growing need wi...
# 15  [{'summary_text': ' Longest edge refinement al...
# 16  [{'summary_text': ' The wide adoption of agile...
# 17  [{'summary_text': ' Ruled surfaces play an imp...
# 18  [{'summary_text': ' Design is an interactive a...
# 19  [{'summary_text': ' A novel approach for plann...
# 20  [{'summary_text': ' Porous scaffolds with inte...
#                                                   RHS
# 0   [{'summary_text': ' We explore the notion of a...
# 1   [{'summary_text': ' The high coupling between ...
# 2   [{'summary_text': ' A geometry seam consists o...
# 3   [{'summary_text': ' This paper presents an alg...
# 4   [{'summary_text': ' The proposed hybrid method...
# 5   [{'summary_text': ' In most cases designers ha...
# 6   [{'summary_text': ' PLM uses intelligent produ...
# 7   [{'summary_text': ' Human body modeling is a c...
# 8   [{'summary_text': ' Family Mould Cavity Runner...
# 9   [{'summary_text': ' In this paper we present a...
# 10  [{'summary_text': ' In an industrial context m...
# 11  [{'summary_text': ' We present an algorithm fo...
# 12  [{'summary_text': ' Solving polynomial systems...
# 13  [{'summary_text': ' The PAL which has a front ...
# 14  [{'summary_text': ' There is a growing need wi...
# 15  [{'summary_text': ' Longest edge refinement al...
# 16  [{'summary_text': ' The wide adoption of agile...
# 17  [{'summary_text': ' Ruled surfaces play an imp...
# 18  [{'summary_text': ' Design is an interactive a...
# 19  [{'summary_text': ' A novel approach for plann...
# 20  [{'summary_text': ' Porous scaffolds with inte...
# 21  [{'summary_text': ' The representation and man...
#                                                   RHS
# 0   [{'summary_text': ' We explore the notion of a...
# 1   [{'summary_text': ' The high coupling between ...
# 2   [{'summary_text': ' A geometry seam consists o...
# 3   [{'summary_text': ' This paper presents an alg...
# 4   [{'summary_text': ' The proposed hybrid method...
# 5   [{'summary_text': ' In most cases designers ha...
# 6   [{'summary_text': ' PLM uses intelligent produ...
# 7   [{'summary_text': ' Human body modeling is a c...
# 8   [{'summary_text': ' Family Mould Cavity Runner...
# 9   [{'summary_text': ' In this paper we present a...
# 10  [{'summary_text': ' In an industrial context m...
# 11  [{'summary_text': ' We present an algorithm fo...
# 12  [{'summary_text': ' Solving polynomial systems...
# 13  [{'summary_text': ' The PAL which has a front ...
# 14  [{'summary_text': ' There is a growing need wi...
# 15  [{'summary_text': ' Longest edge refinement al...
# 16  [{'summary_text': ' The wide adoption of agile...
# 17  [{'summary_text': ' Ruled surfaces play an imp...
# 18  [{'summary_text': ' Design is an interactive a...
# 19  [{'summary_text': ' A novel approach for plann...
# 20  [{'summary_text': ' Porous scaffolds with inte...
# 21  [{'summary_text': ' The representation and man...
# 22  [{'summary_text': ' 3D CAD systems are used in...
#                                                   RHS
# 0   [{'summary_text': ' We explore the notion of a...
# 1   [{'summary_text': ' The high coupling between ...
# 2   [{'summary_text': ' A geometry seam consists o...
# 3   [{'summary_text': ' This paper presents an alg...
# 4   [{'summary_text': ' The proposed hybrid method...
# 5   [{'summary_text': ' In most cases designers ha...
# 6   [{'summary_text': ' PLM uses intelligent produ...
# 7   [{'summary_text': ' Human body modeling is a c...
# 8   [{'summary_text': ' Family Mould Cavity Runner...
# 9   [{'summary_text': ' In this paper we present a...
# 10  [{'summary_text': ' In an industrial context m...
# 11  [{'summary_text': ' We present an algorithm fo...
# 12  [{'summary_text': ' Solving polynomial systems...
# 13  [{'summary_text': ' The PAL which has a front ...
# 14  [{'summary_text': ' There is a growing need wi...
# 15  [{'summary_text': ' Longest edge refinement al...
# 16  [{'summary_text': ' The wide adoption of agile...
# 17  [{'summary_text': ' Ruled surfaces play an imp...
# 18  [{'summary_text': ' Design is an interactive a...
# 19  [{'summary_text': ' A novel approach for plann...
# 20  [{'summary_text': ' Porous scaffolds with inte...
# 21  [{'summary_text': ' The representation and man...
# 22  [{'summary_text': ' 3D CAD systems are used in...
# 23  [{'summary_text': ' The approach combines an e...
#                                                   RHS
# 0   [{'summary_text': ' We explore the notion of a...
# 1   [{'summary_text': ' The high coupling between ...
# 2   [{'summary_text': ' A geometry seam consists o...
# 3   [{'summary_text': ' This paper presents an alg...
# 4   [{'summary_text': ' The proposed hybrid method...
# 5   [{'summary_text': ' In most cases designers ha...
# 6   [{'summary_text': ' PLM uses intelligent produ...
# 7   [{'summary_text': ' Human body modeling is a c...
# 8   [{'summary_text': ' Family Mould Cavity Runner...
# 9   [{'summary_text': ' In this paper we present a...
# 10  [{'summary_text': ' In an industrial context m...
# 11  [{'summary_text': ' We present an algorithm fo...
# 12  [{'summary_text': ' Solving polynomial systems...
# 13  [{'summary_text': ' The PAL which has a front ...
# 14  [{'summary_text': ' There is a growing need wi...
# 15  [{'summary_text': ' Longest edge refinement al...
# 16  [{'summary_text': ' The wide adoption of agile...
# 17  [{'summary_text': ' Ruled surfaces play an imp...
# 18  [{'summary_text': ' Design is an interactive a...
# 19  [{'summary_text': ' A novel approach for plann...
# 20  [{'summary_text': ' Porous scaffolds with inte...
# 21  [{'summary_text': ' The representation and man...
# 22  [{'summary_text': ' 3D CAD systems are used in...
# 23  [{'summary_text': ' The approach combines an e...
# 24  [{'summary_text': ' Being able to automaticall...
#                                                   RHS
# 0   [{'summary_text': ' We explore the notion of a...
# 1   [{'summary_text': ' The high coupling between ...
# 2   [{'summary_text': ' A geometry seam consists o...
# 3   [{'summary_text': ' This paper presents an alg...
# 4   [{'summary_text': ' The proposed hybrid method...
# 5   [{'summary_text': ' In most cases designers ha...
# 6   [{'summary_text': ' PLM uses intelligent produ...
# 7   [{'summary_text': ' Human body modeling is a c...
# 8   [{'summary_text': ' Family Mould Cavity Runner...
# 9   [{'summary_text': ' In this paper we present a...
# 10  [{'summary_text': ' In an industrial context m...
# 11  [{'summary_text': ' We present an algorithm fo...
# 12  [{'summary_text': ' Solving polynomial systems...
# 13  [{'summary_text': ' The PAL which has a front ...
# 14  [{'summary_text': ' There is a growing need wi...
# 15  [{'summary_text': ' Longest edge refinement al...
# 16  [{'summary_text': ' The wide adoption of agile...
# 17  [{'summary_text': ' Ruled surfaces play an imp...
# 18  [{'summary_text': ' Design is an interactive a...
# 19  [{'summary_text': ' A novel approach for plann...
# 20  [{'summary_text': ' Porous scaffolds with inte...
# 21  [{'summary_text': ' The representation and man...
# 22  [{'summary_text': ' 3D CAD systems are used in...
# 23  [{'summary_text': ' The approach combines an e...
# 24  [{'summary_text': ' Being able to automaticall...
# 25  [{'summary_text': ' In this paper we present a...
#                                                   RHS
# 0   [{'summary_text': ' We explore the notion of a...
# 1   [{'summary_text': ' The high coupling between ...
# 2   [{'summary_text': ' A geometry seam consists o...
# 3   [{'summary_text': ' This paper presents an alg...
# 4   [{'summary_text': ' The proposed hybrid method...
# 5   [{'summary_text': ' In most cases designers ha...
# 6   [{'summary_text': ' PLM uses intelligent produ...
# 7   [{'summary_text': ' Human body modeling is a c...
# 8   [{'summary_text': ' Family Mould Cavity Runner...
# 9   [{'summary_text': ' In this paper we present a...
# 10  [{'summary_text': ' In an industrial context m...
# 11  [{'summary_text': ' We present an algorithm fo...
# 12  [{'summary_text': ' Solving polynomial systems...
# 13  [{'summary_text': ' The PAL which has a front ...
# 14  [{'summary_text': ' There is a growing need wi...
# 15  [{'summary_text': ' Longest edge refinement al...
# 16  [{'summary_text': ' The wide adoption of agile...
# 17  [{'summary_text': ' Ruled surfaces play an imp...
# 18  [{'summary_text': ' Design is an interactive a...
# 19  [{'summary_text': ' A novel approach for plann...
# 20  [{'summary_text': ' Porous scaffolds with inte...
# 21  [{'summary_text': ' The representation and man...
# 22  [{'summary_text': ' 3D CAD systems are used in...
# 23  [{'summary_text': ' The approach combines an e...
# 24  [{'summary_text': ' Being able to automaticall...
# 25  [{'summary_text': ' In this paper we present a...
# 26  [{'summary_text': ' Various abstraction techni...
# Your max_length is set to 100, but you input_length is only 98. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=49)
#                                                   RHS
# 0   [{'summary_text': ' We explore the notion of a...
# 1   [{'summary_text': ' The high coupling between ...
# 2   [{'summary_text': ' A geometry seam consists o...
# 3   [{'summary_text': ' This paper presents an alg...
# 4   [{'summary_text': ' The proposed hybrid method...
# 5   [{'summary_text': ' In most cases designers ha...
# 6   [{'summary_text': ' PLM uses intelligent produ...
# 7   [{'summary_text': ' Human body modeling is a c...
# 8   [{'summary_text': ' Family Mould Cavity Runner...
# 9   [{'summary_text': ' In this paper we present a...
# 10  [{'summary_text': ' In an industrial context m...
# 11  [{'summary_text': ' We present an algorithm fo...
# 12  [{'summary_text': ' Solving polynomial systems...
# 13  [{'summary_text': ' The PAL which has a front ...
# 14  [{'summary_text': ' There is a growing need wi...
# 15  [{'summary_text': ' Longest edge refinement al...
# 16  [{'summary_text': ' The wide adoption of agile...
# 17  [{'summary_text': ' Ruled surfaces play an imp...
# 18  [{'summary_text': ' Design is an interactive a...
# 19  [{'summary_text': ' A novel approach for plann...
# 20  [{'summary_text': ' Porous scaffolds with inte...
# 21  [{'summary_text': ' The representation and man...
# 22  [{'summary_text': ' 3D CAD systems are used in...
# 23  [{'summary_text': ' The approach combines an e...
# 24  [{'summary_text': ' Being able to automaticall...
# 25  [{'summary_text': ' In this paper we present a...
# 26  [{'summary_text': ' Various abstraction techni...
# 27  [{'summary_text': ' In this paper we present a...
#                                                   RHS
# 0   [{'summary_text': ' We explore the notion of a...
# 1   [{'summary_text': ' The high coupling between ...
# 2   [{'summary_text': ' A geometry seam consists o...
# 3   [{'summary_text': ' This paper presents an alg...
# 4   [{'summary_text': ' The proposed hybrid method...
# 5   [{'summary_text': ' In most cases designers ha...
# 6   [{'summary_text': ' PLM uses intelligent produ...
# 7   [{'summary_text': ' Human body modeling is a c...
# 8   [{'summary_text': ' Family Mould Cavity Runner...
# 9   [{'summary_text': ' In this paper we present a...
# 10  [{'summary_text': ' In an industrial context m...
# 11  [{'summary_text': ' We present an algorithm fo...
# 12  [{'summary_text': ' Solving polynomial systems...
# 13  [{'summary_text': ' The PAL which has a front ...
# 14  [{'summary_text': ' There is a growing need wi...
# 15  [{'summary_text': ' Longest edge refinement al...
# 16  [{'summary_text': ' The wide adoption of agile...
# 17  [{'summary_text': ' Ruled surfaces play an imp...
# 18  [{'summary_text': ' Design is an interactive a...
# 19  [{'summary_text': ' A novel approach for plann...
# 20  [{'summary_text': ' Porous scaffolds with inte...
# 21  [{'summary_text': ' The representation and man...
# 22  [{'summary_text': ' 3D CAD systems are used in...
# 23  [{'summary_text': ' The approach combines an e...
# 24  [{'summary_text': ' Being able to automaticall...
# 25  [{'summary_text': ' In this paper we present a...
# 26  [{'summary_text': ' Various abstraction techni...
# 27  [{'summary_text': ' In this paper we present a...
# 28  [{'summary_text': ' The rounding algorithm red...
#                                                   RHS
# 0   [{'summary_text': ' We explore the notion of a...
# 1   [{'summary_text': ' The high coupling between ...
# 2   [{'summary_text': ' A geometry seam consists o...
# 3   [{'summary_text': ' This paper presents an alg...
# 4   [{'summary_text': ' The proposed hybrid method...
# 5   [{'summary_text': ' In most cases designers ha...
# 6   [{'summary_text': ' PLM uses intelligent produ...
# 7   [{'summary_text': ' Human body modeling is a c...
# 8   [{'summary_text': ' Family Mould Cavity Runner...
# 9   [{'summary_text': ' In this paper we present a...
# 10  [{'summary_text': ' In an industrial context m...
# 11  [{'summary_text': ' We present an algorithm fo...
# 12  [{'summary_text': ' Solving polynomial systems...
# 13  [{'summary_text': ' The PAL which has a front ...
# 14  [{'summary_text': ' There is a growing need wi...
# 15  [{'summary_text': ' Longest edge refinement al...
# 16  [{'summary_text': ' The wide adoption of agile...
# 17  [{'summary_text': ' Ruled surfaces play an imp...
# 18  [{'summary_text': ' Design is an interactive a...
# 19  [{'summary_text': ' A novel approach for plann...
# 20  [{'summary_text': ' Porous scaffolds with inte...
# 21  [{'summary_text': ' The representation and man...
# 22  [{'summary_text': ' 3D CAD systems are used in...
# 23  [{'summary_text': ' The approach combines an e...
# 24  [{'summary_text': ' Being able to automaticall...
# 25  [{'summary_text': ' In this paper we present a...
# 26  [{'summary_text': ' Various abstraction techni...
# 27  [{'summary_text': ' In this paper we present a...
# 28  [{'summary_text': ' The rounding algorithm red...
# 29  [{'summary_text': ' This paper presents a swep...
#                                                   RHS
# 0   [{'summary_text': ' We explore the notion of a...
# 1   [{'summary_text': ' The high coupling between ...
# 2   [{'summary_text': ' A geometry seam consists o...
# 3   [{'summary_text': ' This paper presents an alg...
# 4   [{'summary_text': ' The proposed hybrid method...
# 5   [{'summary_text': ' In most cases designers ha...
# 6   [{'summary_text': ' PLM uses intelligent produ...
# 7   [{'summary_text': ' Human body modeling is a c...
# 8   [{'summary_text': ' Family Mould Cavity Runner...
# 9   [{'summary_text': ' In this paper we present a...
# 10  [{'summary_text': ' In an industrial context m...
# 11  [{'summary_text': ' We present an algorithm fo...
# 12  [{'summary_text': ' Solving polynomial systems...
# 13  [{'summary_text': ' The PAL which has a front ...
# 14  [{'summary_text': ' There is a growing need wi...
# 15  [{'summary_text': ' Longest edge refinement al...
# 16  [{'summary_text': ' The wide adoption of agile...
# 17  [{'summary_text': ' Ruled surfaces play an imp...
# 18  [{'summary_text': ' Design is an interactive a...
# 19  [{'summary_text': ' A novel approach for plann...
# 20  [{'summary_text': ' Porous scaffolds with inte...
# 21  [{'summary_text': ' The representation and man...
# 22  [{'summary_text': ' 3D CAD systems are used in...
# 23  [{'summary_text': ' The approach combines an e...
# 24  [{'summary_text': ' Being able to automaticall...
# 25  [{'summary_text': ' In this paper we present a...
# 26  [{'summary_text': ' Various abstraction techni...
# 27  [{'summary_text': ' In this paper we present a...
# 28  [{'summary_text': ' The rounding algorithm red...
# 29  [{'summary_text': ' This paper presents a swep...
# 30  [{'summary_text': ' Engineering features are r...
#                                                   RHS
# 0   [{'summary_text': ' We explore the notion of a...
# 1   [{'summary_text': ' The high coupling between ...
# 2   [{'summary_text': ' A geometry seam consists o...
# 3   [{'summary_text': ' This paper presents an alg...
# 4   [{'summary_text': ' The proposed hybrid method...
# 5   [{'summary_text': ' In most cases designers ha...
# 6   [{'summary_text': ' PLM uses intelligent produ...
# 7   [{'summary_text': ' Human body modeling is a c...
# 8   [{'summary_text': ' Family Mould Cavity Runner...
# 9   [{'summary_text': ' In this paper we present a...
# 10  [{'summary_text': ' In an industrial context m...
# 11  [{'summary_text': ' We present an algorithm fo...
# 12  [{'summary_text': ' Solving polynomial systems...
# 13  [{'summary_text': ' The PAL which has a front ...
# 14  [{'summary_text': ' There is a growing need wi...
# 15  [{'summary_text': ' Longest edge refinement al...
# 16  [{'summary_text': ' The wide adoption of agile...
# 17  [{'summary_text': ' Ruled surfaces play an imp...
# 18  [{'summary_text': ' Design is an interactive a...
# 19  [{'summary_text': ' A novel approach for plann...
# 20  [{'summary_text': ' Porous scaffolds with inte...
# 21  [{'summary_text': ' The representation and man...
# 22  [{'summary_text': ' 3D CAD systems are used in...
# 23  [{'summary_text': ' The approach combines an e...
# 24  [{'summary_text': ' Being able to automaticall...
# 25  [{'summary_text': ' In this paper we present a...
# 26  [{'summary_text': ' Various abstraction techni...
# 27  [{'summary_text': ' In this paper we present a...
# 28  [{'summary_text': ' The rounding algorithm red...
# 29  [{'summary_text': ' This paper presents a swep...
# 30  [{'summary_text': ' Engineering features are r...
# 31  [{'summary_text': ' Affective computing involv...
#                                                   RHS
# 0   [{'summary_text': ' We explore the notion of a...
# 1   [{'summary_text': ' The high coupling between ...
# 2   [{'summary_text': ' A geometry seam consists o...
# 3   [{'summary_text': ' This paper presents an alg...
# 4   [{'summary_text': ' The proposed hybrid method...
# 5   [{'summary_text': ' In most cases designers ha...
# 6   [{'summary_text': ' PLM uses intelligent produ...
# 7   [{'summary_text': ' Human body modeling is a c...
# 8   [{'summary_text': ' Family Mould Cavity Runner...
# 9   [{'summary_text': ' In this paper we present a...
# 10  [{'summary_text': ' In an industrial context m...
# 11  [{'summary_text': ' We present an algorithm fo...
# 12  [{'summary_text': ' Solving polynomial systems...
# 13  [{'summary_text': ' The PAL which has a front ...
# 14  [{'summary_text': ' There is a growing need wi...
# 15  [{'summary_text': ' Longest edge refinement al...
# 16  [{'summary_text': ' The wide adoption of agile...
# 17  [{'summary_text': ' Ruled surfaces play an imp...
# 18  [{'summary_text': ' Design is an interactive a...
# 19  [{'summary_text': ' A novel approach for plann...
# 20  [{'summary_text': ' Porous scaffolds with inte...
# 21  [{'summary_text': ' The representation and man...
# 22  [{'summary_text': ' 3D CAD systems are used in...
# 23  [{'summary_text': ' The approach combines an e...
# 24  [{'summary_text': ' Being able to automaticall...
# 25  [{'summary_text': ' In this paper we present a...
# 26  [{'summary_text': ' Various abstraction techni...
# 27  [{'summary_text': ' In this paper we present a...
# 28  [{'summary_text': ' The rounding algorithm red...
# 29  [{'summary_text': ' This paper presents a swep...
# 30  [{'summary_text': ' Engineering features are r...
# 31  [{'summary_text': ' Affective computing involv...
# 32  [{'summary_text': ' This paper presents automa...
#                                                   RHS
# 0   [{'summary_text': ' We explore the notion of a...
# 1   [{'summary_text': ' The high coupling between ...
# 2   [{'summary_text': ' A geometry seam consists o...
# 3   [{'summary_text': ' This paper presents an alg...
# 4   [{'summary_text': ' The proposed hybrid method...
# 5   [{'summary_text': ' In most cases designers ha...
# 6   [{'summary_text': ' PLM uses intelligent produ...
# 7   [{'summary_text': ' Human body modeling is a c...
# 8   [{'summary_text': ' Family Mould Cavity Runner...
# 9   [{'summary_text': ' In this paper we present a...
# 10  [{'summary_text': ' In an industrial context m...
# 11  [{'summary_text': ' We present an algorithm fo...
# 12  [{'summary_text': ' Solving polynomial systems...
# 13  [{'summary_text': ' The PAL which has a front ...
# 14  [{'summary_text': ' There is a growing need wi...
# 15  [{'summary_text': ' Longest edge refinement al...
# 16  [{'summary_text': ' The wide adoption of agile...
# 17  [{'summary_text': ' Ruled surfaces play an imp...
# 18  [{'summary_text': ' Design is an interactive a...
# 19  [{'summary_text': ' A novel approach for plann...
# 20  [{'summary_text': ' Porous scaffolds with inte...
# 21  [{'summary_text': ' The representation and man...
# 22  [{'summary_text': ' 3D CAD systems are used in...
# 23  [{'summary_text': ' The approach combines an e...
# 24  [{'summary_text': ' Being able to automaticall...
# 25  [{'summary_text': ' In this paper we present a...
# 26  [{'summary_text': ' Various abstraction techni...
# 27  [{'summary_text': ' In this paper we present a...
# 28  [{'summary_text': ' The rounding algorithm red...
# 29  [{'summary_text': ' This paper presents a swep...
# 30  [{'summary_text': ' Engineering features are r...
# 31  [{'summary_text': ' Affective computing involv...
# 32  [{'summary_text': ' This paper presents automa...
# 33  [{'summary_text': ' A construction tree is a s...
#                                                   RHS
# 0   [{'summary_text': ' We explore the notion of a...
# 1   [{'summary_text': ' The high coupling between ...
# 2   [{'summary_text': ' A geometry seam consists o...
# 3   [{'summary_text': ' This paper presents an alg...
# 4   [{'summary_text': ' The proposed hybrid method...
# 5   [{'summary_text': ' In most cases designers ha...
# 6   [{'summary_text': ' PLM uses intelligent produ...
# 7   [{'summary_text': ' Human body modeling is a c...
# 8   [{'summary_text': ' Family Mould Cavity Runner...
# 9   [{'summary_text': ' In this paper we present a...
# 10  [{'summary_text': ' In an industrial context m...
# 11  [{'summary_text': ' We present an algorithm fo...
# 12  [{'summary_text': ' Solving polynomial systems...
# 13  [{'summary_text': ' The PAL which has a front ...
# 14  [{'summary_text': ' There is a growing need wi...
# 15  [{'summary_text': ' Longest edge refinement al...
# 16  [{'summary_text': ' The wide adoption of agile...
# 17  [{'summary_text': ' Ruled surfaces play an imp...
# 18  [{'summary_text': ' Design is an interactive a...
# 19  [{'summary_text': ' A novel approach for plann...
# 20  [{'summary_text': ' Porous scaffolds with inte...
# 21  [{'summary_text': ' The representation and man...
# 22  [{'summary_text': ' 3D CAD systems are used in...
# 23  [{'summary_text': ' The approach combines an e...
# 24  [{'summary_text': ' Being able to automaticall...
# 25  [{'summary_text': ' In this paper we present a...
# 26  [{'summary_text': ' Various abstraction techni...
# 27  [{'summary_text': ' In this paper we present a...
# 28  [{'summary_text': ' The rounding algorithm red...
# 29  [{'summary_text': ' This paper presents a swep...
# 30  [{'summary_text': ' Engineering features are r...
# 31  [{'summary_text': ' Affective computing involv...
# 32  [{'summary_text': ' This paper presents automa...
# 33  [{'summary_text': ' A construction tree is a s...
# 34  [{'summary_text': ' In modern industry conditi...
#                                                   RHS
# 0   [{'summary_text': ' We explore the notion of a...
# 1   [{'summary_text': ' The high coupling between ...
# 2   [{'summary_text': ' A geometry seam consists o...
# 3   [{'summary_text': ' This paper presents an alg...
# 4   [{'summary_text': ' The proposed hybrid method...
# 5   [{'summary_text': ' In most cases designers ha...
# 6   [{'summary_text': ' PLM uses intelligent produ...
# 7   [{'summary_text': ' Human body modeling is a c...
# 8   [{'summary_text': ' Family Mould Cavity Runner...
# 9   [{'summary_text': ' In this paper we present a...
# 10  [{'summary_text': ' In an industrial context m...
# 11  [{'summary_text': ' We present an algorithm fo...
# 12  [{'summary_text': ' Solving polynomial systems...
# 13  [{'summary_text': ' The PAL which has a front ...
# 14  [{'summary_text': ' There is a growing need wi...
# 15  [{'summary_text': ' Longest edge refinement al...
# 16  [{'summary_text': ' The wide adoption of agile...
# 17  [{'summary_text': ' Ruled surfaces play an imp...
# 18  [{'summary_text': ' Design is an interactive a...
# 19  [{'summary_text': ' A novel approach for plann...
# 20  [{'summary_text': ' Porous scaffolds with inte...
# 21  [{'summary_text': ' The representation and man...
# 22  [{'summary_text': ' 3D CAD systems are used in...
# 23  [{'summary_text': ' The approach combines an e...
# 24  [{'summary_text': ' Being able to automaticall...
# 25  [{'summary_text': ' In this paper we present a...
# 26  [{'summary_text': ' Various abstraction techni...
# 27  [{'summary_text': ' In this paper we present a...
# 28  [{'summary_text': ' The rounding algorithm red...
# 29  [{'summary_text': ' This paper presents a swep...
# 30  [{'summary_text': ' Engineering features are r...
# 31  [{'summary_text': ' Affective computing involv...
# 32  [{'summary_text': ' This paper presents automa...
# 33  [{'summary_text': ' A construction tree is a s...
# 34  [{'summary_text': ' In modern industry conditi...
# 35  [{'summary_text': ' Research in material behav...
#                                                   RHS
# 0   [{'summary_text': ' We explore the notion of a...
# 1   [{'summary_text': ' The high coupling between ...
# 2   [{'summary_text': ' A geometry seam consists o...
# 3   [{'summary_text': ' This paper presents an alg...
# 4   [{'summary_text': ' The proposed hybrid method...
# 5   [{'summary_text': ' In most cases designers ha...
# 6   [{'summary_text': ' PLM uses intelligent produ...
# 7   [{'summary_text': ' Human body modeling is a c...
# 8   [{'summary_text': ' Family Mould Cavity Runner...
# 9   [{'summary_text': ' In this paper we present a...
# 10  [{'summary_text': ' In an industrial context m...
# 11  [{'summary_text': ' We present an algorithm fo...
# 12  [{'summary_text': ' Solving polynomial systems...
# 13  [{'summary_text': ' The PAL which has a front ...
# 14  [{'summary_text': ' There is a growing need wi...
# 15  [{'summary_text': ' Longest edge refinement al...
# 16  [{'summary_text': ' The wide adoption of agile...
# 17  [{'summary_text': ' Ruled surfaces play an imp...
# 18  [{'summary_text': ' Design is an interactive a...
# 19  [{'summary_text': ' A novel approach for plann...
# 20  [{'summary_text': ' Porous scaffolds with inte...
# 21  [{'summary_text': ' The representation and man...
# 22  [{'summary_text': ' 3D CAD systems are used in...
# 23  [{'summary_text': ' The approach combines an e...
# 24  [{'summary_text': ' Being able to automaticall...
# 25  [{'summary_text': ' In this paper we present a...
# 26  [{'summary_text': ' Various abstraction techni...
# 27  [{'summary_text': ' In this paper we present a...
# 28  [{'summary_text': ' The rounding algorithm red...
# 29  [{'summary_text': ' This paper presents a swep...
# 30  [{'summary_text': ' Engineering features are r...
# 31  [{'summary_text': ' Affective computing involv...
# 32  [{'summary_text': ' This paper presents automa...
# 33  [{'summary_text': ' A construction tree is a s...
# 34  [{'summary_text': ' In modern industry conditi...
# 35  [{'summary_text': ' Research in material behav...
# 36  [{'summary_text': ' In this paper we propose a...
#                                                   RHS
# 0   [{'summary_text': ' We explore the notion of a...
# 1   [{'summary_text': ' The high coupling between ...
# 2   [{'summary_text': ' A geometry seam consists o...
# 3   [{'summary_text': ' This paper presents an alg...
# 4   [{'summary_text': ' The proposed hybrid method...
# 5   [{'summary_text': ' In most cases designers ha...
# 6   [{'summary_text': ' PLM uses intelligent produ...
# 7   [{'summary_text': ' Human body modeling is a c...
# 8   [{'summary_text': ' Family Mould Cavity Runner...
# 9   [{'summary_text': ' In this paper we present a...
# 10  [{'summary_text': ' In an industrial context m...
# 11  [{'summary_text': ' We present an algorithm fo...
# 12  [{'summary_text': ' Solving polynomial systems...
# 13  [{'summary_text': ' The PAL which has a front ...
# 14  [{'summary_text': ' There is a growing need wi...
# 15  [{'summary_text': ' Longest edge refinement al...
# 16  [{'summary_text': ' The wide adoption of agile...
# 17  [{'summary_text': ' Ruled surfaces play an imp...
# 18  [{'summary_text': ' Design is an interactive a...
# 19  [{'summary_text': ' A novel approach for plann...
# 20  [{'summary_text': ' Porous scaffolds with inte...
# 21  [{'summary_text': ' The representation and man...
# 22  [{'summary_text': ' 3D CAD systems are used in...
# 23  [{'summary_text': ' The approach combines an e...
# 24  [{'summary_text': ' Being able to automaticall...
# 25  [{'summary_text': ' In this paper we present a...
# 26  [{'summary_text': ' Various abstraction techni...
# 27  [{'summary_text': ' In this paper we present a...
# 28  [{'summary_text': ' The rounding algorithm red...
# 29  [{'summary_text': ' This paper presents a swep...
# 30  [{'summary_text': ' Engineering features are r...
# 31  [{'summary_text': ' Affective computing involv...
# 32  [{'summary_text': ' This paper presents automa...
# 33  [{'summary_text': ' A construction tree is a s...
# 34  [{'summary_text': ' In modern industry conditi...
# 35  [{'summary_text': ' Research in material behav...
# 36  [{'summary_text': ' In this paper we propose a...
# 37  [{'summary_text': ' In this article we present...
#                                                   RHS
# 0   [{'summary_text': ' We explore the notion of a...
# 1   [{'summary_text': ' The high coupling between ...
# 2   [{'summary_text': ' A geometry seam consists o...
# 3   [{'summary_text': ' This paper presents an alg...
# 4   [{'summary_text': ' The proposed hybrid method...
# 5   [{'summary_text': ' In most cases designers ha...
# 6   [{'summary_text': ' PLM uses intelligent produ...
# 7   [{'summary_text': ' Human body modeling is a c...
# 8   [{'summary_text': ' Family Mould Cavity Runner...
# 9   [{'summary_text': ' In this paper we present a...
# 10  [{'summary_text': ' In an industrial context m...
# 11  [{'summary_text': ' We present an algorithm fo...
# 12  [{'summary_text': ' Solving polynomial systems...
# 13  [{'summary_text': ' The PAL which has a front ...
# 14  [{'summary_text': ' There is a growing need wi...
# 15  [{'summary_text': ' Longest edge refinement al...
# 16  [{'summary_text': ' The wide adoption of agile...
# 17  [{'summary_text': ' Ruled surfaces play an imp...
# 18  [{'summary_text': ' Design is an interactive a...
# 19  [{'summary_text': ' A novel approach for plann...
# 20  [{'summary_text': ' Porous scaffolds with inte...
# 21  [{'summary_text': ' The representation and man...
# 22  [{'summary_text': ' 3D CAD systems are used in...
# 23  [{'summary_text': ' The approach combines an e...
# 24  [{'summary_text': ' Being able to automaticall...
# 25  [{'summary_text': ' In this paper we present a...
# 26  [{'summary_text': ' Various abstraction techni...
# 27  [{'summary_text': ' In this paper we present a...
# 28  [{'summary_text': ' The rounding algorithm red...
# 29  [{'summary_text': ' This paper presents a swep...
# 30  [{'summary_text': ' Engineering features are r...
# 31  [{'summary_text': ' Affective computing involv...
# 32  [{'summary_text': ' This paper presents automa...
# 33  [{'summary_text': ' A construction tree is a s...
# 34  [{'summary_text': ' In modern industry conditi...
# 35  [{'summary_text': ' Research in material behav...
# 36  [{'summary_text': ' In this paper we propose a...
# 37  [{'summary_text': ' In this article we present...
# 38  [{'summary_text': ' This paper is an overview ...
#                                                   RHS
# 0   [{'summary_text': ' We explore the notion of a...
# 1   [{'summary_text': ' The high coupling between ...
# 2   [{'summary_text': ' A geometry seam consists o...
# 3   [{'summary_text': ' This paper presents an alg...
# 4   [{'summary_text': ' The proposed hybrid method...
# 5   [{'summary_text': ' In most cases designers ha...
# 6   [{'summary_text': ' PLM uses intelligent produ...
# 7   [{'summary_text': ' Human body modeling is a c...
# 8   [{'summary_text': ' Family Mould Cavity Runner...
# 9   [{'summary_text': ' In this paper we present a...
# 10  [{'summary_text': ' In an industrial context m...
# 11  [{'summary_text': ' We present an algorithm fo...
# 12  [{'summary_text': ' Solving polynomial systems...
# 13  [{'summary_text': ' The PAL which has a front ...
# 14  [{'summary_text': ' There is a growing need wi...
# 15  [{'summary_text': ' Longest edge refinement al...
# 16  [{'summary_text': ' The wide adoption of agile...
# 17  [{'summary_text': ' Ruled surfaces play an imp...
# 18  [{'summary_text': ' Design is an interactive a...
# 19  [{'summary_text': ' A novel approach for plann...
# 20  [{'summary_text': ' Porous scaffolds with inte...
# 21  [{'summary_text': ' The representation and man...
# 22  [{'summary_text': ' 3D CAD systems are used in...
# 23  [{'summary_text': ' The approach combines an e...
# 24  [{'summary_text': ' Being able to automaticall...
# 25  [{'summary_text': ' In this paper we present a...
# 26  [{'summary_text': ' Various abstraction techni...
# 27  [{'summary_text': ' In this paper we present a...
# 28  [{'summary_text': ' The rounding algorithm red...
# 29  [{'summary_text': ' This paper presents a swep...
# 30  [{'summary_text': ' Engineering features are r...
# 31  [{'summary_text': ' Affective computing involv...
# 32  [{'summary_text': ' This paper presents automa...
# 33  [{'summary_text': ' A construction tree is a s...
# 34  [{'summary_text': ' In modern industry conditi...
# 35  [{'summary_text': ' Research in material behav...
# 36  [{'summary_text': ' In this paper we propose a...
# 37  [{'summary_text': ' In this article we present...
# 38  [{'summary_text': ' This paper is an overview ...
# 39  [{'summary_text': ' Charged particulate spray ...
#                                                   RHS
# 0   [{'summary_text': ' We explore the notion of a...
# 1   [{'summary_text': ' The high coupling between ...
# 2   [{'summary_text': ' A geometry seam consists o...
# 3   [{'summary_text': ' This paper presents an alg...
# 4   [{'summary_text': ' The proposed hybrid method...
# 5   [{'summary_text': ' In most cases designers ha...
# 6   [{'summary_text': ' PLM uses intelligent produ...
# 7   [{'summary_text': ' Human body modeling is a c...
# 8   [{'summary_text': ' Family Mould Cavity Runner...
# 9   [{'summary_text': ' In this paper we present a...
# 10  [{'summary_text': ' In an industrial context m...
# 11  [{'summary_text': ' We present an algorithm fo...
# 12  [{'summary_text': ' Solving polynomial systems...
# 13  [{'summary_text': ' The PAL which has a front ...
# 14  [{'summary_text': ' There is a growing need wi...
# 15  [{'summary_text': ' Longest edge refinement al...
# 16  [{'summary_text': ' The wide adoption of agile...
# 17  [{'summary_text': ' Ruled surfaces play an imp...
# 18  [{'summary_text': ' Design is an interactive a...
# 19  [{'summary_text': ' A novel approach for plann...
# 20  [{'summary_text': ' Porous scaffolds with inte...
# 21  [{'summary_text': ' The representation and man...
# ...
# 73  [{'summary_text': ' In this paper a robust alg...
# 74  [{'summary_text': ' In this paper the authors ...
# 75  [{'summary_text': ' The main roadblock that ha...
# 76  [{'summary_text': ' This paper presents a stud...
#
# [77 rows x 1 columns]
#                                                   RHS
# 0   [{'summary_text': ' We explore the notion of a...
# 1   [{'summary_text': ' The high coupling between ...
# 2   [{'summary_text': ' A geometry seam consists o...
# 3   [{'summary_text': ' This paper presents an alg...
# 4   [{'summary_text': ' The proposed hybrid method...
# ..                                                ...
# 73  [{'summary_text': ' In this paper a robust alg...
# 74  [{'summary_text': ' In this paper the authors ...
# 75  [{'summary_text': ' The main roadblock that ha...
# 76  [{'summary_text': ' This paper presents a stud...
# 77  [{'summary_text': ' Spiral tool paths eliminat...
#
# [78 rows x 1 columns]
#                                                   RHS
# 0   [{'summary_text': ' We explore the notion of a...
# 1   [{'summary_text': ' The high coupling between ...
# 2   [{'summary_text': ' A geometry seam consists o...
# 3   [{'summary_text': ' This paper presents an alg...
# 4   [{'summary_text': ' The proposed hybrid method...
# ..                                                ...
# 74  [{'summary_text': ' In this paper the authors ...
# 75  [{'summary_text': ' The main roadblock that ha...
# 76  [{'summary_text': ' This paper presents a stud...
# 77  [{'summary_text': ' Spiral tool paths eliminat...
# 78  [{'summary_text': ' Real time physics simulati...
#
# [79 rows x 1 columns]
#                                                   RHS
# 0   [{'summary_text': ' We explore the notion of a...
# 1   [{'summary_text': ' The high coupling between ...
# 2   [{'summary_text': ' A geometry seam consists o...
# 3   [{'summary_text': ' This paper presents an alg...
# 4   [{'summary_text': ' The proposed hybrid method...
# ..                                                ...
# 75  [{'summary_text': ' The main roadblock that ha...
# 76  [{'summary_text': ' This paper presents a stud...
# 77  [{'summary_text': ' Spiral tool paths eliminat...
# 78  [{'summary_text': ' Real time physics simulati...
# 79  [{'summary_text': ' Two reversible watermarkin...
#
# [80 rows x 1 columns]
#                                                   RHS
# 0   [{'summary_text': ' We explore the notion of a...
# 1   [{'summary_text': ' The high coupling between ...
# 2   [{'summary_text': ' A geometry seam consists o...
# 3   [{'summary_text': ' This paper presents an alg...
# 4   [{'summary_text': ' The proposed hybrid method...
# ..                                                ...
# 76  [{'summary_text': ' This paper presents a stud...
# 77  [{'summary_text': ' Spiral tool paths eliminat...
# 78  [{'summary_text': ' Real time physics simulati...
# 79  [{'summary_text': ' Two reversible watermarkin...
# 80  [{'summary_text': ' Path oriented computer con...
#
# [81 rows x 1 columns]
#                                                   RHS
# 0   [{'summary_text': ' We explore the notion of a...
# 1   [{'summary_text': ' The high coupling between ...
# 2   [{'summary_text': ' A geometry seam consists o...
# 3   [{'summary_text': ' This paper presents an alg...
# 4   [{'summary_text': ' The proposed hybrid method...
# ..                                                ...
# 77  [{'summary_text': ' Spiral tool paths eliminat...
# 78  [{'summary_text': ' Real time physics simulati...
# 79  [{'summary_text': ' Two reversible watermarkin...
# 80  [{'summary_text': ' Path oriented computer con...
# 81  [{'summary_text': ' In order to robustly perfo...
#
# [82 rows x 1 columns]
# Your max_length is set to 100, but you input_length is only 74. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=37)
#                                                   RHS
# 0   [{'summary_text': ' We explore the notion of a...
# 1   [{'summary_text': ' The high coupling between ...
# 2   [{'summary_text': ' A geometry seam consists o...
# 3   [{'summary_text': ' This paper presents an alg...
# 4   [{'summary_text': ' The proposed hybrid method...
# ..                                                ...
# 78  [{'summary_text': ' Real time physics simulati...
# 79  [{'summary_text': ' Two reversible watermarkin...
# 80  [{'summary_text': ' Path oriented computer con...
# 81  [{'summary_text': ' In order to robustly perfo...
# 82  [{'summary_text': ' A self expandable stent wi...
#
# [83 rows x 1 columns]
#                                                   RHS
# 0   [{'summary_text': ' We explore the notion of a...
# 1   [{'summary_text': ' The high coupling between ...
# 2   [{'summary_text': ' A geometry seam consists o...
# 3   [{'summary_text': ' This paper presents an alg...
# 4   [{'summary_text': ' The proposed hybrid method...
# ..                                                ...
# 79  [{'summary_text': ' Two reversible watermarkin...
# 80  [{'summary_text': ' Path oriented computer con...
# 81  [{'summary_text': ' In order to robustly perfo...
# 82  [{'summary_text': ' A self expandable stent wi...
# 83  [{'summary_text': ' In this paper we propose a...
#
# [84 rows x 1 columns]
#                                                   RHS
# 0   [{'summary_text': ' We explore the notion of a...
# 1   [{'summary_text': ' The high coupling between ...
# 2   [{'summary_text': ' A geometry seam consists o...
# 3   [{'summary_text': ' This paper presents an alg...
# 4   [{'summary_text': ' The proposed hybrid method...
# ..                                                ...
# 80  [{'summary_text': ' Path oriented computer con...
# 81  [{'summary_text': ' In order to robustly perfo...
# 82  [{'summary_text': ' A self expandable stent wi...
# 83  [{'summary_text': ' In this paper we propose a...
# 84  [{'summary_text': ' For a common class of 2D m...
#
# [85 rows x 1 columns]
#                                                   RHS
# 0   [{'summary_text': ' We explore the notion of a...
# 1   [{'summary_text': ' The high coupling between ...
# 2   [{'summary_text': ' A geometry seam consists o...
# 3   [{'summary_text': ' This paper presents an alg...
# 4   [{'summary_text': ' The proposed hybrid method...
# ..                                                ...
# 81  [{'summary_text': ' In order to robustly perfo...
# 82  [{'summary_text': ' A self expandable stent wi...
# 83  [{'summary_text': ' In this paper we propose a...
# 84  [{'summary_text': ' For a common class of 2D m...
# 85  [{'summary_text': ' In this paper we present a...
#
# [86 rows x 1 columns]
#                                                   RHS
# 0   [{'summary_text': ' We explore the notion of a...
# 1   [{'summary_text': ' The high coupling between ...
# 2   [{'summary_text': ' A geometry seam consists o...
# 3   [{'summary_text': ' This paper presents an alg...
# 4   [{'summary_text': ' The proposed hybrid method...
# ..                                                ...
# 82  [{'summary_text': ' A self expandable stent wi...
# 83  [{'summary_text': ' In this paper we propose a...
# 84  [{'summary_text': ' For a common class of 2D m...
# 85  [{'summary_text': ' In this paper we present a...
# 86  [{'summary_text': ' This paper proposes a nove...
#
# [87 rows x 1 columns]
#                                                   RHS
# 0   [{'summary_text': ' We explore the notion of a...
# 1   [{'summary_text': ' The high coupling between ...
# 2   [{'summary_text': ' A geometry seam consists o...
# 3   [{'summary_text': ' This paper presents an alg...
# 4   [{'summary_text': ' The proposed hybrid method...
# ..                                                ...
# 83  [{'summary_text': ' In this paper we propose a...
# 84  [{'summary_text': ' For a common class of 2D m...
# 85  [{'summary_text': ' In this paper we present a...
# 86  [{'summary_text': ' This paper proposes a nove...
# 87  [{'summary_text': ' Surface subdivision gains ...
#
# [88 rows x 1 columns]
#                                                   RHS
# 0   [{'summary_text': ' We explore the notion of a...
# 1   [{'summary_text': ' The high coupling between ...
# 2   [{'summary_text': ' A geometry seam consists o...
# 3   [{'summary_text': ' This paper presents an alg...
# 4   [{'summary_text': ' The proposed hybrid method...
# ..                                                ...
# 84  [{'summary_text': ' For a common class of 2D m...
# 85  [{'summary_text': ' In this paper we present a...
# 86  [{'summary_text': ' This paper proposes a nove...
# 87  [{'summary_text': ' Surface subdivision gains ...
# 88  [{'summary_text': ' In this work a new hole pa...
#
# [89 rows x 1 columns]
# Your max_length is set to 100, but you input_length is only 89. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=44)
#                                                   RHS
# 0   [{'summary_text': ' We explore the notion of a...
# 1   [{'summary_text': ' The high coupling between ...
# 2   [{'summary_text': ' A geometry seam consists o...
# 3   [{'summary_text': ' This paper presents an alg...
# 4   [{'summary_text': ' The proposed hybrid method...
# ..                                                ...
# 85  [{'summary_text': ' In this paper we present a...
# 86  [{'summary_text': ' This paper proposes a nove...
# 87  [{'summary_text': ' Surface subdivision gains ...
# 88  [{'summary_text': ' In this work a new hole pa...
# 89  [{'summary_text': ' We introduce and study a n...
#
# [90 rows x 1 columns]
#                                                   RHS
# 0   [{'summary_text': ' We explore the notion of a...
# 1   [{'summary_text': ' The high coupling between ...
# 2   [{'summary_text': ' A geometry seam consists o...
# 3   [{'summary_text': ' This paper presents an alg...
# 4   [{'summary_text': ' The proposed hybrid method...
# ..                                                ...
# 86  [{'summary_text': ' This paper proposes a nove...
# 87  [{'summary_text': ' Surface subdivision gains ...
# 88  [{'summary_text': ' In this work a new hole pa...
# 89  [{'summary_text': ' We introduce and study a n...
# 90  [{'summary_text': ' The best known isotropic m...
#
# [91 rows x 1 columns]
#                                                   RHS
# 0   [{'summary_text': ' We explore the notion of a...
# 1   [{'summary_text': ' The high coupling between ...
# 2   [{'summary_text': ' A geometry seam consists o...
# 3   [{'summary_text': ' This paper presents an alg...
# 4   [{'summary_text': ' The proposed hybrid method...
# ..                                                ...
# 87  [{'summary_text': ' Surface subdivision gains ...
# 88  [{'summary_text': ' In this work a new hole pa...
# 89  [{'summary_text': ' We introduce and study a n...
# 90  [{'summary_text': ' The best known isotropic m...
# 91  [{'summary_text': ' Surface development is use...
#
# [92 rows x 1 columns]
#                                                   RHS
# 0   [{'summary_text': ' We explore the notion of a...
# 1   [{'summary_text': ' The high coupling between ...
# 2   [{'summary_text': ' A geometry seam consists o...
# 3   [{'summary_text': ' This paper presents an alg...
# 4   [{'summary_text': ' The proposed hybrid method...
# ..                                                ...
# 88  [{'summary_text': ' In this work a new hole pa...
# 89  [{'summary_text': ' We introduce and study a n...
# 90  [{'summary_text': ' The best known isotropic m...
# 91  [{'summary_text': ' Surface development is use...
# 92  [{'summary_text': ' We propose a method to ext...
#
# [93 rows x 1 columns]
#                                                   RHS
# 0   [{'summary_text': ' We explore the notion of a...
# 1   [{'summary_text': ' The high coupling between ...
# 2   [{'summary_text': ' A geometry seam consists o...
# 3   [{'summary_text': ' This paper presents an alg...
# 4   [{'summary_text': ' The proposed hybrid method...
# ..                                                ...
# 89  [{'summary_text': ' We introduce and study a n...
# 90  [{'summary_text': ' The best known isotropic m...
# 91  [{'summary_text': ' Surface development is use...
# 92  [{'summary_text': ' We propose a method to ext...
# 93  [{'summary_text': ' Design activities body mov...
#
# [94 rows x 1 columns]
#                                                   RHS
# 0   [{'summary_text': ' We explore the notion of a...
# 1   [{'summary_text': ' The high coupling between ...
# 2   [{'summary_text': ' A geometry seam consists o...
# 3   [{'summary_text': ' This paper presents an alg...
# 4   [{'summary_text': ' The proposed hybrid method...
# ..                                                ...
# 90  [{'summary_text': ' The best known isotropic m...
# 91  [{'summary_text': ' Surface development is use...
# 92  [{'summary_text': ' We propose a method to ext...
# 93  [{'summary_text': ' Design activities body mov...
# 94  [{'summary_text': ' This paper presents an eff...
#
# [95 rows x 1 columns]
#                                                   RHS
# 0   [{'summary_text': ' We explore the notion of a...
# 1   [{'summary_text': ' The high coupling between ...
# 2   [{'summary_text': ' A geometry seam consists o...
# 3   [{'summary_text': ' This paper presents an alg...
# 4   [{'summary_text': ' The proposed hybrid method...
# ..                                                ...
# 91  [{'summary_text': ' Surface development is use...
# 92  [{'summary_text': ' We propose a method to ext...
# 93  [{'summary_text': ' Design activities body mov...
# 94  [{'summary_text': ' This paper presents an eff...
# 95  [{'summary_text': ' Fashion Design is an indus...
#
# [96 rows x 1 columns]
#                                                   RHS
# 0   [{'summary_text': ' We explore the notion of a...
# 1   [{'summary_text': ' The high coupling between ...
# 2   [{'summary_text': ' A geometry seam consists o...
# 3   [{'summary_text': ' This paper presents an alg...
# 4   [{'summary_text': ' The proposed hybrid method...
# ..                                                ...
# 92  [{'summary_text': ' We propose a method to ext...
# 93  [{'summary_text': ' Design activities body mov...
# 94  [{'summary_text': ' This paper presents an eff...
# 95  [{'summary_text': ' Fashion Design is an indus...
# 96  [{'summary_text': ' Advances in Information an...
#
# [97 rows x 1 columns]
#                                                   RHS
# 0   [{'summary_text': ' We explore the notion of a...
# 1   [{'summary_text': ' The high coupling between ...
# 2   [{'summary_text': ' A geometry seam consists o...
# 3   [{'summary_text': ' This paper presents an alg...
# 4   [{'summary_text': ' The proposed hybrid method...
# ..                                                ...
# 93  [{'summary_text': ' Design activities body mov...
# 94  [{'summary_text': ' This paper presents an eff...
# 95  [{'summary_text': ' Fashion Design is an indus...
# 96  [{'summary_text': ' Advances in Information an...
# 97  [{'summary_text': ' The developed method has b...
#
# [98 rows x 1 columns]
#                                                   RHS
# 0   [{'summary_text': ' We explore the notion of a...
# 1   [{'summary_text': ' The high coupling between ...
# 2   [{'summary_text': ' A geometry seam consists o...
# 3   [{'summary_text': ' This paper presents an alg...
# 4   [{'summary_text': ' The proposed hybrid method...
# ..                                                ...
# 94  [{'summary_text': ' This paper presents an eff...
# 95  [{'summary_text': ' Fashion Design is an indus...
# 96  [{'summary_text': ' Advances in Information an...
# 97  [{'summary_text': ' The developed method has b...
# 98  [{'summary_text': ' GaFinC can track precise h...
#
# [99 rows x 1 columns]
#                                                   RHS
# 0   [{'summary_text': ' We explore the notion of a...
# 1   [{'summary_text': ' The high coupling between ...
# 2   [{'summary_text': ' A geometry seam consists o...
# 3   [{'summary_text': ' This paper presents an alg...
# 4   [{'summary_text': ' The proposed hybrid method...
# ..                                                ...
# 95  [{'summary_text': ' Fashion Design is an indus...
# 96  [{'summary_text': ' Advances in Information an...
# 97  [{'summary_text': ' The developed method has b...
# 98  [{'summary_text': ' GaFinC can track precise h...
# 99  [{'summary_text': ' The system takes as input ...
#
# [100 rows x 1 columns]

# %%
df1.to_csv('summary2.csv')
